# %%
import os
from dotenv import load_dotenv, dotenv_values
from openai import OpenAI
import pandas as pd

# %%
load_dotenv()
# Out:
# True

# %%
openai_client = OpenAI(
  api_key= os.getenv("OPENAI_API_KEY")
)

# %%
all_models = openai_client.models.list()

# %%
list(all_models)

# %%
pd.DataFrame(list(all_models))
# Out:
#                                     0                      1                2  \
# 0                      (id, dall-e-2)  (created, 1698798177)  (object, model)
# 1            (id, o1-mini-2024-09-12)  (created, 1725648979)  (object, model)
# 2         (id, o1-preview-2024-09-12)  (created, 1725648865)  (object, model)
# 3                       (id, o1-mini)  (created, 1725649008)  (object, model)
# 4                    (id, o1-preview)  (created, 1725648897)  (object, model)
# 5                     (id, whisper-1)  (created, 1677532384)  (object, model)
# 6                      (id, dall-e-3)  (created, 1698785189)  (object, model)
# 7                   (id, babbage-002)  (created, 1692634615)  (object, model)
# 8        (id, omni-moderation-latest)  (created, 1731689265)  (object, model)
# 9    (id, omni-moderation-2024-09-26)  (created, 1732734466)  (object, model)
# 10                (id, tts-1-hd-1106)  (created, 1699053533)  (object, model)
# ...
